# %% [markdown]
# <a href="https://colab.research.google.com/github/azimjaan21/EV_data2024/blob/main/Global_EV_Data_2024.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Global Electric Vehicle Sales Data (2010-2024)
# Comprehensive EV Sales Trends & Growth Insights Across the Globe (2010-2024)
#
# ![image.png](data:image/png;base64,...)

# %%
import numpy as np
import pandas as pd

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df = pd.read_csv('EVData2024.csv', index_col=0)
df.head()
# Out:
#              category       parameter  mode powertrain  year      unit  \
# region
# Australia  Historical  EV stock share  Cars         EV  2011   percent
# Australia  Historical  EV sales share  Cars         EV  2011   percent
# Australia  Historical        EV sales  Cars        BEV  2011  Vehicles
# Australia  Historical        EV stock  Cars        BEV  2011  Vehicles
# Australia  Historical        EV stock  Cars        BEV  2012  Vehicles
#
#                value
# region
# Australia    0.00039
# Australia    0.00650
# Australia   49.00000
# Australia   49.00000
# Australia  220.00000
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_18['year'].plot(kind='hist', bins=20, title='year')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# ...

# %% [markdown]
# # Seaborn

# %% [markdown]
# ```
# # This is formatted as code
# ```
#
# # .lineplot ()

# %%
plt.figure(figsize=(10,5))
plt.title('Global Electric Vehicle Sales Data')
plt.xlabel('Countries')
plt.ylabel('Years')
plt.xticks(rotation=90)
plt.grid(True)
sns.lineplot(data=df['year'])
plt.show()

# %% [markdown]
# # .barplot ()

# %% [markdown]
# **South Korea Visitors**
#
# *Foreign visitors into South Korea*

# %%
df = pd.read_csv('Enter_korea_by_purpose.csv', index_col=0)
df.head()
# Out:
#            nation  visitor     growth      share  tourism  business  \
# date
# 2019-1      China   392814  28.737870  35.555117   320113      2993
# 2019-1      Japan   206526  23.606830  18.693468   198805      2233
# 2019-1     Taiwan    87954  16.003693   7.961057    86393        74
# 2019-1  Hong Kong    35896   3.533212   3.249086    34653        59
# 2019-1      Macao     2570 -12.376406   0.232621     2506         2
#
#         official affairs  studying  others
# date
# 2019-1               138      8793   60777
# 2019-1               127       785    4576
# 2019-1                22       180    1285
# 2019-1                 2        90    1092
# 2019-1                 0        17      45

# %% [markdown]
# Context
# This dataset deals with the visitors of foreigners into South Korea.
# It includes foreigners(not Korean), overseas Koreans and crew members, except for some of the foreign arrivals who are not considered tourists (diplomats, soldiers, permanent residents, visiting cohabitation and residence).
#
# The Korea Tourism Organization (KTO) has compiled, analyzed, and provided statistics on foreign tourists visiting Korea and overseas tourists by type.
# The data materials were prepared for the purpose of utilizing them as basic data for establishing tourism policies and marketing strategies.
#
# I created this dataset by rebuilding the data provided by KTO for easy analysis.
#
# Content
# This data set is divided into three files (age, gender, and propose).
# ![lotte.jpeg](data:image/jpeg;base64,...)

# %%
plt.figure(figsize=(10,5))
plt.title('Foreign visitors into South Korea')
plt.xlabel('Nations')
plt.ylabel('Number of visitors')
sns.barplot(x=df['nation'], y=df['visitor'])
plt.grid()
plt.xticks(rotation=90)
plt.show()
